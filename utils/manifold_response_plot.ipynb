# %%
import sys, os
import itertools

import numpy as np
import time
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import squareform
from sklearn.metrics.cluster import adjusted_rand_score
from matplotlib import pyplot as plt
import scipy.io as sio

import nibabel as nib
import nilearn
from nilearn import image
from nilearn import plotting
from nilearn import datasets

import seaborn as sns
# %load_ext autoreload
# %autoreload 2
# Out:
# /Users/siyuangao/miniconda3/envs/py27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
xilin_parc = '/Users/siyuangao/Working_Space/fmri/data/shen_1mm_268_parcellation.nii'

# %%
file = sio.loadmat('/Users/siyuangao/Working_Space/fmri/code_siyuan/2018summer/2sDM/output/task_response.mat')
c_all = file['c_all']

# %%
np.shape(c_all)
# Out:
# (268, 4)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][0]+269

data[data<=268] = 0
data[data>0] -= 269

array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='high level cognition', vmin=0, vmax=1.1)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][1]+269

data[data<=268] = 0
data[data>0] -= 269



array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='low level cognition', vmin=0, vmax=1.1)
# Out:
# /Users/siyuangao/miniconda3/envs/py27/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][2]+269

data[data<=268] = 0
data[data>0] -= 269


array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='fixation', vmin=0, vmax=1.1)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][3]+269

data[data<=268] = 0
data[data>0] -= 269


array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='transient', vmin=0, vmax=1.1)
# Out:
# /Users/siyuangao/miniconda3/envs/py27/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# # No zscore

# %%
file = sio.loadmat('/Users/siyuangao/Working_Space/fmri/code_siyuan/2018summer/2sDM/output/task_response_raw4.mat')
c_all = file['c_all']

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][0]+269

data[data<=268] = 0
data[data>0] -= 269

array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='high level cognition')

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][1]+269

data[data<=268] = 0
data[data>0] -= 269



array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='fixation')

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][2]+269

data[data<=268] = 0
data[data>0] -= 269


array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='low level cognition (motor)')

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][3]+269

data[data<=268] = 0
data[data>0] -= 269


array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='transient')

# %% [markdown]
# # No zscore

# %%
file = sio.loadmat('/Users/siyuangao/Working_Space/fmri/code_siyuan/2018summer/2sDM/output/task_response_raw6.mat')
c_all = file['c_all']

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][0]+269

data[data<=268] = 0
data[data>0] -= 269

array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='Fixation')

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][1]+269

data[data<=268] = 0
data[data>0] -= 269



array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='Relational')

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][2]+269

data[data<=268] = 0
data[data>0] -= 269


array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='2back')

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][3]+269

data[data<=268] = 0
data[data>0] -= 269


array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='transient or cue')

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][4]+269

data[data<=268] = 0
data[data>0] -= 269


array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='social')

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][5]+269

data[data<=268] = 0
data[data>0] -= 269


array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='0back')

# %% [markdown]
# # Extension inner low cognition

# %%
file = sio.loadmat('/Users/siyuangao/Working_Space/fmri/code_siyuan/2018summer/2sDM/output/extension/all_response_innerlow.mat')
c_all = file['all_response']

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][0][2]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
# nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='low_response', plot_abs=False, vmin=-2, vmax=2)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, plot_abs=False, vmin=-2, vmax=2)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][1][2]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
# nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='ext_low_response', plot_abs=False, vmin=-2, vmax=2)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, plot_abs=False, vmin=-2, vmax=2)

# %% [markdown]
# # Extension sanity check

# %%
file = sio.loadmat('/Users/siyuangao/Working_Space/fmri/code_siyuan/2018summer/2sDM/output/extension/all_response.mat')
c_all = file['all_response']

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][0][0]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
# nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='fix_response', plot_abs=False, vmin=-2, vmax=2)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True,  plot_abs=False, vmin=-2, vmax=2)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][1][0]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
# nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='ext_fix_response', plot_abs=False, vmin=-2, vmax=2)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, plot_abs=False, vmin=-2, vmax=2)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][0][1]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
# nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='cue_response', plot_abs=False, vmin=-2, vmax=2)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, plot_abs=False, vmin=-2, vmax=2)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][1][1]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
# nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='ext_cue_response', plot_abs=False, vmin=-2, vmax=2)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, plot_abs=False, vmin=-2, vmax=2)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][0][2]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
# nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='low_response', plot_abs=False, vmin=-2, vmax=2)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, plot_abs=False, vmin=-2, vmax=2)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][1][2]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
# nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='ext_low_response', plot_abs=False, vmin=-2, vmax=2)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, plot_abs=False, vmin=-2, vmax=2)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][0][3]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
# nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='high_response', plot_abs=False, vmin=-2, vmax=2)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, plot_abs=False, vmin=-2, vmax=2)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][1][3]+269

data[data<=268] = 0
data[data>0] -= 269

array_img = nib.Nifti1Image(data, img.affine)
# nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='ext_high_response', plot_abs=False, vmin=-2, vmax=2)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, plot_abs=False, vmin=-2, vmax=2)

# %% [markdown]
# # Raw response

# %%
file = sio.loadmat('/Users/siyuangao/Working_Space/fmri/code_siyuan/2018summer/2sDM/output/extension/all_response_raw.mat')
c_all = file['all_response']

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][0][0]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='fix_response', plot_abs=False)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][1][0]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='ext_fix_response', plot_abs=False)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][0][1]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='cue_response', plot_abs=False)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][1][1]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='ext_cue_response', plot_abs=False)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][0][2]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='low_response', plot_abs=False)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][1][2]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='ext_low_response', plot_abs=False)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][0][3]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='high_response', plot_abs=False)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][1][3]+500

data[data<=268] = 0
data[data>0] -= 500

array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='ext_high_response', plot_abs=False)

# %%
img = nib.load(xilin_parc)
data = img.get_fdata()

for i in xrange(1,269):
    data[data==i] = c_all[i-1][1][3]+500

data[data<=268] = 0
data[data>0] -= 500
data[data<0]=0
array_img = nib.Nifti1Image(data, img.affine)
nilearn.plotting.plot_glass_brain(array_img, colorbar=True, title='ext_high_response', plot_abs=False)

# %% [markdown]
# # Barplots with seabron

# %%
import seaborn as sns
import pandas as pd

# %%
file = sio.loadmat('/Users/siyuangao/Working_Space/fmri/code_siyuan/2018summer/2sDM/output/extension/dwell_time_list.mat')
dwell_time_list = file['dwell_time_list']
name = ['higher level cognition','transition','fixation','lower level cognition']
df = pd.DataFrame(dwell_time_list, columns=name)

# %%
sns.set(font_scale=1.5)
sns.set_style("white")
fig, ax = plt.subplots(figsize=(10,5))
clrs = [[0.30196,0.6862745,0.00392], [0.21568,0.4941176,0.72156], [0.8941176,0.10196,0.1098],[0.5961,0.3059,0.6392]]
sns.barplot(data=df, ax=ax, capsize=0.1, palette=clrs, linewidth=3, edgecolor=".1")
sns.despine()
fig.savefig('dwell_time.png')

# %%
file = sio.loadmat('/Users/siyuangao/Working_Space/fmri/code_siyuan/2018summer/2sDM/output/extension/dwell_time100.mat')
dwell_time_list = file['dwell_time_list']
dwell_time_list = dwell_time_list[:, (1, 2, 0, 3)]
name = ['higher level cognition','transition','fixation','lower level cognition']
df = pd.DataFrame(dwell_time_list, columns=name)

# %%
sns.set(font_scale=1.5)
sns.set_style("white")
fig, ax = plt.subplots(figsize=(10,5))
clrs = [[0.30196,0.6862745,0.00392], [0.21568,0.4941176,0.72156], [0.8941176,0.10196,0.1098],[0.5961,0.3059,0.6392]]
sns.barplot(data=df, ax=ax, capsize=0.1, palette=clrs, linewidth=3, edgecolor=".1")
sns.despine()
fig.savefig('dwell_time.png')

# %%
file = sio.loadmat('/Users/siyuangao/Working_Space/fmri/code_siyuan/2018summer/2sDM/output/extension/dwell_time30_5382.mat')
dwell_time_list = file['dwell_time_list']
# dwell_time_list = dwell_time_list[:, (1, 2, 0, 3)]
name = ['higher level cognition','transition','fixation','lower level cognition']
df = pd.DataFrame(dwell_time_list, columns=name)

# %%
sns.set(font_scale=1.5)
sns.set_style("white")
fig, ax = plt.subplots(figsize=(10,5))
clrs = [[0.30196,0.6862745,0.00392], [0.21568,0.4941176,0.72156], [0.8941176,0.10196,0.1098],[0.5961,0.3059,0.6392]]
sns.barplot(data=df, ax=ax, capsize=0.1, palette=clrs, linewidth=3, edgecolor=".1")
sns.despine()
fig.savefig('dwell_time.png')

# %%
file = sio.loadmat('/Users/siyuangao/Working_Space/fmri/code_siyuan/2018summer/2sDM/output/extension/dwell_time390_5420zscore.mat')
dwell_time_list = file['dwell_time_list']
dwell_time_list = dwell_time_list[:, (3,2,0,1)]
name = ['higher-level cognition','transition','fixation','lower-level cognition']
df = pd.DataFrame(dwell_time_list, columns=name)

# %%
sns.set(font_scale=1.5)
sns.set_style("white")
fig, ax = plt.subplots(figsize=(10,5))
clrs = [[0.30196,0.6862745,0.00392], [0.21568,0.4941176,0.72156], [0.8941176,0.10196,0.1098],[0.5961,0.3059,0.6392]]
sns.barplot(data=df, ax=ax, capsize=0.1, palette=clrs, linewidth=3, edgecolor=".1", ci="sd")
sns.despine()
fig.savefig('dwell_time.png')

# %% [markdown]
# # Transition matrix

# %%
import seaborn as sns
import pandas as pd

# %%
file = sio.loadmat('/Users/siyuangao/Working_Space/fmri/code_siyuan/2018summer/2sDM/output/extension/trans_mat390.mat')
trans_mat = file['trans_mat']

# %%
sns.set(font_scale=3)
fig, ax = plt.subplots(figsize=(13,10))
ax = sns.heatmap(trans_mat, cmap="YlGnBu", annot=True, linewidths=.5, xticklabels=False, yticklabels=False)
fig.savefig('transition.png')
